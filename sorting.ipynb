# %%
import pandas as pd

# %%
df = pd.read_csv("../data/titanic_test.csv")
df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df.dtypes
# Out:
# PassengerId      int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# ## Sort Ascending

# %%
df.sort_values('Pclass').head()
# Out:
#      PassengerId  Pclass                                               Name  \
# 208         1100       1                      Rosenbaum, Miss. Edith Louise
# 350         1242       1       Greenfield, Mrs. Leo David (Blanche Strouse)
# 122         1014       1                    Schabert, Mrs. Paul (Emma Mock)
# 343         1235       1  Cardeza, Mrs. James Warburton Martinez (Charlo...
# 131         1023       1                          Gracie, Col. Archibald IV
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 208  female  33.0      0      0  PC 17613   27.7208          A11        C
# 350  female  45.0      0      1  PC 17759   63.3583      D10 D12        C
# 122  female  35.0      1      0     13236   57.7500          C28        C
# 343  female  58.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 131    male  53.0      0      0    113780   28.5000          C51        C

# %% [markdown]
# ## Sort Descending

# %%
df.sort_values("Pclass", ascending=False).head()
# Out:
#      PassengerId  Pclass                                       Name     Sex  \
# 0            892       3                           Kelly, Mr. James    male
# 232         1124       3                    Wiklund, Mr. Karl Johan    male
# 249         1141       3  Khalil, Mrs. Betros (Zahie Maria" Elias)"  female
# 244         1136       3  Johnston, Master. William Arthur Willie""    male
# 243         1135       3                         Hyman, Mr. Abraham    male
#
#       Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 0    34.5      0      0      330911   7.8292   NaN        Q
# 232  21.0      1      0     3101266   6.4958   NaN        S
# 249   NaN      1      0        2660  14.4542   NaN        C
# 244   NaN      1      2  W./C. 6607  23.4500   NaN        S
# 243   NaN      0      0        3470   7.8875   NaN        S

# %% [markdown]
# ## Sort Based on 2 Columns

# %%
## first column is sorted, second is sorted as tie breaker
df.sort_values(['Pclass','Embarked']).head()
# Out:
#     PassengerId  Pclass                                             Name  \
# 20          912       1                           Rothschild, Mr. Martin
# 23          915       1                  Williams, Mr. Richard Norris II
# 24          916       1  Ryerson, Mrs. Arthur Larned (Emily Maria Borie)
# 26          918       1                     Ostby, Miss. Helene Ragnhild
# 34          926       1                         Mock, Mr. Philipp Edmund
#
#        Sex   Age  SibSp  Parch    Ticket      Fare            Cabin Embarked
# 20    male  55.0      1      0  PC 17603   59.4000              NaN        C
# 23    male  21.0      0      1  PC 17597   61.3792              NaN        C
# 24  female  48.0      1      3  PC 17608  262.3750  B57 B59 B63 B66        C
# 26  female  22.0      0      1    113509   61.9792              B36        C
# 34    male  30.0      1      0     13236   57.7500              C78        C

# %% [markdown]
# ## Sort Strings

# %%
df.sort_values("Name").head()
# Out:
#      PassengerId  Pclass                                       Name     Sex  \
# 392         1284       3              Abbott, Master. Eugene Joseph    male
# 345         1237       3                Abelseth, Miss. Karen Marie  female
# 57           949       3              Abelseth, Mr. Olaus Jorgensen    male
# 251         1143       3   Abrahamsson, Mr. Abraham August Johannes    male
# 8            900       3  Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female
#
#       Age  SibSp  Parch            Ticket     Fare  Cabin Embarked
# 392  13.0      0      2         C.A. 2673  20.2500    NaN        S
# 345  16.0      0      0            348125   7.6500    NaN        S
# 57   25.0      0      0            348122   7.6500  F G63        S
# 251  20.0      0      0  SOTON/O2 3101284   7.9250    NaN        S
# 8    18.0      0      0              2657   7.2292    NaN        C

# %% [markdown]
# ## Does Case Matter in Sorting... Yes?

# %%
df.loc[392, 'Name'] = 'abbott, Master. Eugene Joseph'

# %%
df.sort_values("Name").head()
# Out:
#      PassengerId  Pclass                                       Name     Sex  \
# 345         1237       3                Abelseth, Miss. Karen Marie  female
# 57           949       3              Abelseth, Mr. Olaus Jorgensen    male
# 251         1143       3   Abrahamsson, Mr. Abraham August Johannes    male
# 8            900       3  Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female
# 307         1199       3                  Aks, Master. Philip Frank    male
#
#        Age  SibSp  Parch            Ticket    Fare  Cabin Embarked
# 345  16.00      0      0            348125  7.6500    NaN        S
# 57   25.00      0      0            348122  7.6500  F G63        S
# 251  20.00      0      0  SOTON/O2 3101284  7.9250    NaN        S
# 8    18.00      0      0              2657  7.2292    NaN        C
# 307   0.83      0      1            392091  9.3500    NaN        S
