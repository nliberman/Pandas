# %%
import pandas as pd

# %%
df = pd.read_csv("../data/titanic_test.csv")

# %%
df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df.loc[0,'PassengerId']
# Out:
# 892

# %%
df.set_index("Name", inplace=True)

# %%
df.head()
# Out:
#                                               PassengerId  Pclass     Sex  \
# Name
# Kelly, Mr. James                                      892       3    male
# Wilkes, Mrs. James (Ellen Needs)                      893       3  female
# Myles, Mr. Thomas Francis                             894       2    male
# Wirz, Mr. Albert                                      895       3    male
# Hirvonen, Mrs. Alexander (Helga E Lindqvist)          896       3  female
#
#                                                Age  SibSp  Parch   Ticket  \
# Name
# Kelly, Mr. James                              34.5      0      0   330911
# Wilkes, Mrs. James (Ellen Needs)              47.0      1      0   363272
# Myles, Mr. Thomas Francis                     62.0      0      0   240276
# Wirz, Mr. Albert                              27.0      0      0   315154
# Hirvonen, Mrs. Alexander (Helga E Lindqvist)  22.0      1      1  3101298
#
#                                                  Fare Cabin Embarked
# Name
# Kelly, Mr. James                               7.8292   NaN        Q
# Wilkes, Mrs. James (Ellen Needs)               7.0000   NaN        S
# Myles, Mr. Thomas Francis                      9.6875   NaN        Q
# Wirz, Mr. Albert                               8.6625   NaN        S
# Hirvonen, Mrs. Alexander (Helga E Lindqvist)  12.2875   NaN        S

# %%
df.loc[0,'PassengerId']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-62f5ef23900e> in <module>()
# ----> 1 df.loc[0,'PassengerId']
#
# /Users/neil/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in __getitem__(self, key)
#    1292
#    1293         if type(key) is tuple:
# -> 1294             return self._getitem_tuple(key)
#    1295         else:
#    1296             return self._getitem_axis(key, axis=0)
#
# /Users/neil/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_tuple(self, tup)
#     782     def _getitem_tuple(self, tup):
#     783         try:
# --> 784             return self._getitem_lowerdim(tup)
#     785         except IndexingError:
#     786             pass
#
# /Users/neil/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_lowerdim(self, tup)
#     906         for i, key in enumerate(tup):
#     907             if is_label_like(key) or isinstance(key, tuple):
# --> 908                 section = self._getitem_axis(key, axis=i)
#     909
#     910                 # we have yielded a scalar ?
#
# /Users/neil/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_axis(self, key, axis)
#    1464
#    1465         # fall thru to straight lookup
# -> 1466         self._has_valid_type(key, axis)
#    1467         return self._get_label(key, axis=axis)
#    1468
#
# /Users/neil/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in _has_valid_type(self, key, axis)
#    1391
#    1392             try:
# -> 1393                 key = self._convert_scalar_indexer(key, axis)
#    1394                 if key not in ax:
#    1395                     error()
#
# /Users/neil/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in _convert_scalar_indexer(self, key, axis)
#     185         ax = self.obj._get_axis(min(axis, self.ndim - 1))
#     186         # a scalar
# --> 187         return ax._convert_scalar_indexer(key, kind=self.name)
#     188
#     189     def _convert_slice_indexer(self, key, axis):
#
# /Users/neil/anaconda/lib/python2.7/site-packages/pandas/indexes/base.pyc in _convert_scalar_indexer(self, key, kind)
#    1010             elif kind in ['loc'] and is_integer(key):
#    1011                 if not self.holds_integer():
# -> 1012                     return self._invalid_indexer('label', key)
#    1013
#    1014         return key
#
# /Users/neil/anaconda/lib/python2.7/site-packages/pandas/indexes/base.pyc in _invalid_indexer(self, form, key)
#    1123                         "indexers [{key}] of {kind}".format(
#    1124                             form=form, klass=type(self), key=key,
# -> 1125                             kind=type(key)))
#    1126
#    1127     def get_duplicates(self):
#
# TypeError: cannot do label indexing on <class 'pandas.indexes.base.Index'> with these indexers [0] of <type 'int'>

# %%
df.loc['Kelly, Mr. James', 'PassengerId']
# Out:
# 892

# %%
## suppose dont want to write out a long index name, can use integers

# %%
df.iloc[0, 0]
# Out:
# 892

# %%
df.iloc[1,0]
# Out:
# 893

# %% [markdown]
# ## Multiple Cols and Rows

# %%
df.head()
# Out:
#                                               PassengerId  Pclass     Sex  \
# Name
# Kelly, Mr. James                                      892       3    male
# Wilkes, Mrs. James (Ellen Needs)                      893       3  female
# Myles, Mr. Thomas Francis                             894       2    male
# Wirz, Mr. Albert                                      895       3    male
# Hirvonen, Mrs. Alexander (Helga E Lindqvist
# Robins, Mr. Alexander A                                     917       3
# Ostby, Miss. Helene Ragnhild                                918       1
# Daher, Mr. Shedid                                           919       3
# Brady, Mr. John Bertram                                     920       1
# Samaan, Mr. Elias                                           921       3
# ...                                                         ...     ...
# Canavan, Mr. Patrick                                       1280       3
# Palsson, Master. Paul Folke                                1281       3
# Payne, Mr. Vivian Ponsonby                                 1282       1
# Lines, Mrs. Ernest H (Elizabeth Lindsey James)             1283       1
# Abbott, Master. Eugene Joseph                              1284       3
# Gilbert, Mr. William                                       1285       2
# Kink-Heilmann, Mr. Anton                                   1286       3
# Smith, Mrs. Lucien Philip (Mary Eloise Hughes)             1287       1
# Colbert, Mr. Patrick                                       1288       3
# Frolicher-Stehli, Mrs. Maxmillian (Margaretha E...         1289       1
# Larsson-Rondberg, Mr. Edvard A                             1290       3
# Conlon, Mr. Thomas Henry                                   1291       3
# Bonnell, Miss. Caroline                                    1292       1
# Gale, Mr. Harry                                            1293       2
# Gibson, Miss. Dorothy Winifred                             1294       1
# Carrau, Mr. Jose Pedro                                     1295       1
# Frauenthal, Mr. Isaac Gerald                               1296       1
# Nourney, Mr. Alfred (Baron von Drachstedt")"               1297       2
# Ware, Mr. William Jeffery                                  1298       2
# Widener, Mr. George Dunton                                 1299       1
# Riordan, Miss. Johanna Hannah""                            1300       3
# Peacock, Miss. Treasteall                                  1301       3
# Naughton, Miss. Hannah                                     1302       3
# Minahan, Mrs. William Edward (Lillian E Thorpe)            1303       1
# Henriksson, Miss. Jenny Lovisa                             1304       3
# Spector, Mr. Woolf                                         1305       3
# Oliva y Ocana, Dona. Fermina                               1306       1
# Saether, Mr. Simon Sivertsen                               1307       3
# Ware, Mr. Frederick                                        1308       3
# Peter, Master. Michael J                                   1309       3
#
# [418 rows x 2 columns]

# %% [markdown]
# ## retrieve value on a filter

# %%
df[df.Ticket=='SC/PARIS 2167']
# Out:
#                                                PassengerId  Pclass     Sex  \
# Name
# del Carlo, Mrs. Sebastiano (Argenia Genovesi)          907       2  female
#
#                                                 Age  SibSp  Parch  \
# Name
# del Carlo, Mrs. Sebastiano (Argenia Genovesi)  24.0      1      0
#
#                                                       Ticket     Fare Cabin  \
# Name
# del Carlo, Mrs. Sebastiano (Argenia Genovesi)  SC/PARIS 2167  27.7208   NaN
#
#                                               Embarked
# Name
# del Carlo, Mrs. Sebastiano (Argenia Genovesi)        C

# %%
df[(df.Pclass==2) & (df.Ticket=='SC/PARIS 2167')].reset_index().loc[0,"Age"]
# Out:
# 24.0

# %%
df[(df.Pclass==2) & (df.Ticket=='SC/PARIS 2167')].reset_index()
# Out:
#                                             Name  PassengerId  Pclass     Sex  \
# 0  del Carlo, Mrs. Sebastiano (Argenia Genovesi)          907       2  female
#
#     Age  SibSp  Parch         Ticket     Fare Cabin Embarked
# 0  24.0      1      0  SC/PARIS 2167  27.7208   NaN        C
